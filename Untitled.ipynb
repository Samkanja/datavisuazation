# %%
def seconds_to_hours(secs):
    return secs/3600

secs = [4500, 6000,2000,4200]
new = list(map(seconds_to_hours,secs))
new
# Out:
# [1.25, 1.6666666666666667, 0.5555555555555556, 1.1666666666666667]

# %%
hours = [4,5,7,8,9,10]
time = list(map(lambda x: x * 3600, hours))
time
# Out:
# [14400, 18000, 25200, 28800, 32400, 36000]

# %%
time = tuple(map(lambda x: x * 3600, hours))
time
# Out:
# (14400, 18000, 25200, 28800, 32400, 36000)

# %%
import pandas as pd
import numpy as np

# %%
marks = [56,78,89,10]
pd.Series(marks)
# Out:
# 0    56
# 1    78
# 2    89
# 3    10
# dtype: int64

# %%
res = {'kanja':48,'grace':82,'mary':43,'john':73,'hannah':90}
df = pd.Series(res)
df
# Out:
# kanja     48
# grace     82
# mary      43
# john      73
# hannah    90
# dtype: int64

# %%
df.loc['hannah']
# Out:
# 90

# %%
df.iloc[3]
# Out:
# 73

# %%
tot = np.sum(df)

# %%
tot
# Out:
# 336

# %%
df.loc['john'] = 30
df
# Out:
# kanja     48
# grace     82
# mary      43
# john      30
# hannah    90
# dtype: int64

# %%
df.loc['kagimbi']=56
df
# Out:
# kanja      48
# grace      82
# mary       43
# john       30
# hannah     90
# kagimbi    56
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(x='total_bill',y='tip',data=df)
plt.xlabel('Total bill')
plt.ylabel('Tips')
plt.show()

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
corr_matrix = df.corr()
corr_matrix['tip'].sort_values(ascending=False)
# Out:
# /tmp/ipykernel_11218/3249794800.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# tip           1.000000
# total_bill    0.675734
# size          0.489299
# Name: tip, dtype: float64

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.pairplot(df,kind='scatter')

# %%
plt.show()

# %%
d = {'Name': pd.Series(['kanja','John','Ngoiri','Njeri','Kagimbi','Grace','Ishmael','Oscar','Nyangara','Litho']),
    'Age': pd.Series([70,45,76,34,81,20,14,43,88,85]),
    'Height': pd.Series([114.0,173.0,124.0,153.4,192.2,172.9,165.9,124.7,136.3,167.4])}
d
# Out:
# {'Name': 0       kanja
#  1        John
#  2      Ngoiri
#  3       Njeri
#  4     Kagimbi
#  5       Grace
#  6     Ishmael
#  7       Oscar
#  8    Nyangara
#  9       Litho
#  dtype: object,
#  'Age': 0    70
#  1    45
#  2    76
#  3    34
#  4    81
#  5    20
#  6    14
#  7    43
#  8    88
#  9    85
#  dtype: int64,
#  'Height': 0    114.0
#  1    173.0
#  2    124.0
#  3    153.4
#  4    192.2
#  5    172.9
#  6    165.9
#  7    124.7
#  8    136.3
#  9    167.4
#  dtype: float64}

# %%
df = pd.DataFrame(d)
df
# Out:
#        Name  Age  Height
# 0     kanja   70   114.0
# 1      John   45   173.0
# 2    Ngoiri   76   124.0
# 3     Njeri   34   153.4
# 4   Kagimbi   81   192.2
# 5     Grace   20   172.9
# 6   Ishmael   14   165.9
# 7     Oscar   43   124.7
# 8  Nyangara   88   136.3
# 9     Litho   85   167.4

# %%
df.mean()
# Out:
# /tmp/ipykernel_11218/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Age        55.60
# Height    152.38
# dtype: float64

# %%
df.describe()
# Out:
#             Age      Height
# count  10.00000   10.000000
# mean   55.60000  152.380000
# std    27.72564   26.128988
# min    14.00000  114.000000
# 25%    36.25000  127.600000
# 50%    57.50000  159.650000
# 75%    79.75000  171.525000
# max    88.00000  192.200000

# %%
dif_list = list(map(lambda x, y : x - y,df['Age'].mean(),df['Age']))
dif_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 dif_list = list(map(lambda x, y : x - y,df['Age'].mean(),df['Age']))
#       2 dif_list
#
# TypeError: 'numpy.float64' object is not iterable

# %%
df['Age'].mean()
# Out:
# 55.6

# %%
df['Age']
# Out:
# 0    70
# 1    45
# 2    76
# 3    34
# 4    81
# 5    20
# 6    14
# 7    43
# 8    88
# 9    85
# Name: Age, dtype: int64

# %%
def variance_cal(df):
    return df['Age'].mean() - df['Age']

diff = list(map(variance_cal,df))
diff
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 def variance_cal(df):
#       2     return df['Age'].mean() - df['Age']
# ----> 4 diff = list(map(variance_cal,df))
#       5 diff
#
# Cell In[31], line 2, in variance_cal(df)
#       1 def variance_cal(df):
# ----> 2     return df['Age'].mean() - df['Age']
#
# TypeError: string indices must be integers

# %%
df.std()
# Out:
# /tmp/ipykernel_11218/3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Age       27.725640
# Height    26.128988
# dtype: float64

# %%
df.median()
# Out:
# /tmp/ipykernel_11218/530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Age        57.50
# Height    159.65
# dtype: float64

# %%
df.mode()
# Out:
#        Name  Age  Height
# 0     Grace   14   114.0
# 1   Ishmael   20   124.0
# 2      John   34   124.7
# 3   Kagimbi   43   136.3
# 4     Litho   45   153.4
# 5    Ngoiri   70   165.9
# 6     Njeri   76   167.4
# 7  Nyangara   81   172.9
# 8     Oscar   85   173.0
# 9     kanja   88   192.2

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Height'], dtype='object')

# %%
plt.scatter(df['Age'],df['Height'])

# %%
plt.scatter(df['Age'],df['Height'])
plt.xlim(0,1000)
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
plt.scatter(df['Age'],df['Height'],s=60,c='red',marker='^')

# %%
plt.scatter(df['Age'],df['Height'],s=60,c='red',marker='^')
plt.title('Age vs Height')
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %%
# %matplotlib inline
plt.scatter(df['Age'],df['Height'],s=60,c='red',marker='^')
plt.title('Age vs Height')
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()
